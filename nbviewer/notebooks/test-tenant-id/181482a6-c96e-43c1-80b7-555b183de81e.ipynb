# %%
from datetime import datetime

now = datetime.now()
current_time = now.strftime("%D %H:%M:%S")
print('BAŞLAMA SAATİ : {}'.format(current_time))

# %%
time.sleep(2.0)

# %%
now = datetime.now()
current_time = now.strftime("%D %H:%M:%S")

print('BİTİŞ SAATİ : {}'.format(current_time))
